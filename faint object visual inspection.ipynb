# %%
from astropy.table import Table

# %%
sn_table = Table.read('SN_withPetroFlux_07302021_rabsmag.txt', format = 'ascii.commented_header')
sn_table
# Out:
# <Table length=1279>
#    event    ...       rabsmag
#    str23    ...       float64
# ----------- ... -------------------
# ASASSN-13dn ... -18.348260828109954
# ASASSN-14az ... -15.652880237784276
# ASASSN-14bu ...  -16.71989451468687
# ASASSN-15bd ... -15.481901638954104
# ASASSN-15ik ... -17.191689745580653
# ASASSN-15mj ... -19.257272558010282
# ASASSN-15mm ... -18.514586295653988
# ASASSN-15no ...  -17.27151865052559
# ASASSN-15rb ... -18.493965547979062
# ASASSN-15tm ... -17.766320384396533
#         ... ...                 ...
#   SN2019hty ...  -19.66955643840825
#   SN2019krw ... -19.707011265249214
#   SN2019lsm ... -18.095635584760974
#   SN2019vxm ... -15.420738887284472
#   SN2020bwr ... -19.050493698066592
#   SN2020euy ... -14.294200495251557
#   SN2020hvn ...  -18.28000717260946
#   SN2021jvn ... -11.445804803688898
# SNLS-04D1ln ...   -18.9826137953489
#   iPTF13daz ...  -20.16086310300778

# %%
faintob_bool = sn_table['rabsmag'] > -15

# %%
faintob_tab = sn_table[faintob_bool]

# %%
faintob_tab['name', 'ra', 'dec', 'rabsmag','z'].show_in_notebook()
# Out:
# <i>Table length=200</i>
# <table id="table4747493968-752714" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>name</th><th>ra</th><th>dec</th><th>rabsmag</th><th>z</th></tr></thead>
# <tr><td>0</td><td>CSS110325:111951-002144</td><td>166.96066666666667</td><td>18.994194444444446</td><td>-11.748187423695333</td><td>0.02</td></tr>
# <tr><td>1</td><td>Gaia14act</td><td>185.09375</td><td>28.414277777777777</td><td>-12.109752253909031</td><td>0.027</td></tr>
# <tr><td>2</td><td>PS15cvn</td><td>2.340291666666667</td><td>0.06847222222222223</td><td>-11.851087377079091</td><td>0.065</td></tr>
# <tr><td>3</td><td>SDSS-II_SN_10054</td><td>47.0405</td><td>0.511198</td><td>-14.331641755773584</td><td>0.078157</td></tr>
# <tr><td>4</td><td>SDSS-II_SN_10672</td><td>341.17</td><td>0.865018</td><td>-14.567972042392789</td><td>0.084961</td></tr>
# ...

# %%
faintob_tab['name', 'ra', 'dec', 'rabsmag','z'].show_in_notebook()
# Out:
# <i>Table length=200</i>
# <table id="table4747493968-752714" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>name</th><th>ra</th><th>dec</th><th>rabsmag</th><th>z</th></tr></thead>
# <tr><td>0</td><td>CSS110325:111951-002144</td><td>166.96066666666667</td><td>18.994194444444446</td><td>-11.748187423695333</td><td>0.02</td></tr>
# <tr><td>1</td><td>Gaia14act</td><td>185.09375</td><td>28.414277777777777</td><td>-12.109752253909031</td><td>0.027</td></tr>
# <tr><td>2</td><td>PS15cvn</td><td>2.340291666666667</td><td>0.06847222222222223</td><td>-11.851087377079091</td><td>0.065</td></tr>
# <tr><td>3</td><td>SDSS-II_SN_10054</td><td>47.0405</td><td>0.511198</td><td>-14.331641755773584</td><td>0.078157</td></tr>
# <tr><td>4</td><td>SDSS-II_SN_10672</td><td>341.17</td><td>0.865018</td><td>-14.567972042392789</td><td>0.084961</td></tr>
# ...

# %%
faintob_tab['name', 'ra', 'dec', 'rabsmag','z'].show_in_notebook()
# Out:
# <i>Table length=200</i>
# <table id="table4747493968-752714" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>name</th><th>ra</th><th>dec</th><th>rabsmag</th><th>z</th></tr></thead>
# <tr><td>0</td><td>CSS110325:111951-002144</td><td>166.96066666666667</td><td>18.994194444444446</td><td>-11.748187423695333</td><td>0.02</td></tr>
# <tr><td>1</td><td>Gaia14act</td><td>185.09375</td><td>28.414277777777777</td><td>-12.109752253909031</td><td>0.027</td></tr>
# <tr><td>2</td><td>PS15cvn</td><td>2.340291666666667</td><td>0.06847222222222223</td><td>-11.851087377079091</td><td>0.065</td></tr>
# <tr><td>3</td><td>SDSS-II_SN_10054</td><td>47.0405</td><td>0.511198</td><td>-14.331641755773584</td><td>0.078157</td></tr>
# <tr><td>4</td><td>SDSS-II_SN_10672</td><td>341.17</td><td>0.865018</td><td>-14.567972042392789</td><td>0.084961</td></tr>
# ...
