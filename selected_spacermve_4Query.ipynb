# %% [markdown]
# Lets remove the spaces in the names themselves on the "name" column

# %%
from astropy.table import Table
import astropy.units as u
import numpy as np

# %%
#lets get our query_table and create a variable for our name column
#nmetab_col = Table.read("query_table.txt", format = 'ascii.commented_header')
# nmetab_col

# %%
# with open('query_table.txt', 'w') as f:
#     f.write('name hostra hostdec\n')
#     for name, hostra, hostdec in nmetab_col:
#         name = name.replace(' ', '_')
#         f.write('{} {} {}\n'.format(name, hostra, hostdec))

# %%
#[n.replace(' ', '_') for n in nmetab_col['name']]

# %%
#lets get our query_table and create a variable for our name column
nmecol_tbSNe = Table.read("selected_z.txt", format = 'ascii.commented_header')
nmecol_tbSNe
# Out:
# <Table length=1851>
#    event    ...    z
#    str23    ... float64
# ----------- ... --------
# ASASSN-14az ... 0.006731
# ASASSN-15bd ... 0.007946
# ASASSN-15tu ...   0.0126
#    PS1-14od ...     0.02
#    SN2002au ...    0.018
#     SN2011D ...   0.0231
#     SN2011V ...   0.0138
#    SN2011bv ...    0.077
#    SN2011cb ...   0.0079
#    SN2011dh ... 0.001638
#         ... ...      ...
#   SN2018dys ...    0.055
#   SN2018fav ... 0.037923
#   SN2018ijp ...   0.0848
#   SN2018ise ...   0.0552
#   SN2018liq ...    0.034
#   SN2019bjv ...   0.0265
#   SN2019dwy ...    0.045
#   SN2019krw ...    0.047
#   SN2019rwq ...   0.0255
#   SN2020euy ... 0.062312

# %%
for i,n in enumerate(nmecol_tbSNe['name']):
    nmecol_tbSNe['name'][i] = n.replace(' ', '_')

# %%
nmecol_tbSNe.show_in_notebook()
# Out:
# <i>Table length=1851</i>
# <table id="table4543857616-891235" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>event</th><th>alias</th><th>catalog</th><th>claimedtype</th><th>dec</th><th>discoverdate</th><th>discoverer</th><th>download</th><th>ebv</th><th>host</th><th>hostdec</th><th>hostoffsetang</th><th>hostoffsetdist</th><th>hostra</th><th>instruments</th><th>lumdist</th><th>maxabsmag</th><th>maxappmag</th><th>maxdate</th><th>name</th><th>photolink</th><th>ra</th><th>radiolink</th><th>redshift</th><th>references</th><th>spectralink</th><th>velocity</th><th>xraylink</th><th>z</th></tr></thead>
# ...

# %%
selectedtb_removed = 'selected_z_nmermve.txt'
nmecol_tbSNe.write(selectedtb_removed, format = 'ascii.commented_header', overwrite = True)

# %%
table = Table.read('selected_z_nmermve.txt', format = 'ascii.commented_header')
table
# Out:
# <Table length=1851>
#    event    ...    z
#    str23    ... float64
# ----------- ... --------
# ASASSN-14az ... 0.006731
# ASASSN-15bd ... 0.007946
# ASASSN-15tu ...   0.0126
#    PS1-14od ...     0.02
#    SN2002au ...    0.018
#     SN2011D ...   0.0231
#     SN2011V ...   0.0138
#    SN2011bv ...    0.077
#    SN2011cb ...   0.0079
#    SN2011dh ... 0.001638
#         ... ...      ...
#   SN2018dys ...    0.055
#   SN2018fav ... 0.037923
#   SN2018ijp ...   0.0848
#   SN2018ise ...   0.0552
#   SN2018liq ...    0.034
#   SN2019bjv ...   0.0265
#   SN2019dwy ...    0.045
#   SN2019krw ...    0.047
#   SN2019rwq ...   0.0255
#   SN2020euy ... 0.062312
